# %%
import pandas as pd
import re
from collections import Counter
from nltk.corpus import stopwords
from PIL import Image
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.util import ngrams
from nltk import word_tokenize
from nltk.corpus import reuters
from collections import Counter, defaultdict
import random

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Andrea Paniagua\\Documents\\6 semestre UVG\\Data science\\HDT5'

# %%
f = open('en_US.blogs.txt', 'r',encoding="utf8")
blogs = f.readlines()
f.close()

# %%
f = open('en_US.twitter.txt', 'r',encoding="utf8")
tweets = f.readlines()
f.close()

# %%
f = open('en_US.news.txt', 'r',encoding="utf8")
news = f.readlines()
f.close()

# %%
###SE eliminaron las mayusculas

# %%
tweets= [i.lower() for i in tweets]
news= [i.lower() for i in news]
blogs= [i.lower() for i in blogs]
tweets
# Out:
# ['how are you? btw thanks for the rt. you gonna be in dc anytime soon? love to see you. been way, way too long.\n',
#  "when you meet someone special... you'll know. your heart will beat more rapidly and you'll smile for no reason.\n",
#  "they've decided its more fun if i don't.\n",
#  'so tired d; played lazer tag & ran a lot d; ughh going to sleep like in 5 minutes ;)\n',
#  'words from a complete stranger! made my birthday even better :)\n',
#  'first cubs game ever! wrigley field is gorgeous. this is perfect. go cubs go!\n',
#  'i no! i get another day off from skool due to the wonderful snow (: and this wakes me up...damn thing\n',
#  "i'm coo... jus at work hella tired r u ever in cali\n",
#  'the new sundrop commercial ...hehe love at first sight\n',
#  'we need to reconnect this week\n',
#  'i always wonder how the guys on the auctions shows learned to talk so fast!? all i hear is djsosnekspqnslanskam.\n',
#  'dammnnnnn what a catch\n',
# ...

# %%
###Se eliminaran los URLS

# %%
tweets=[re.sub('\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*','',i) for i in tweets]
news=[re.sub('\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*','',i) for i in news]
blogs=[re.sub('\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*','',i) for i in blogs]

# %%
###eliminar caracteres especiales

# %%
tweets=[re.sub('[^a-zA-Z0-9 ]+','', i) for i in tweets]
news=[re.sub('[^a-zA-Z0-9 ]+', '', i) for i in news]
blogs=[re.sub('[^a-zA-Z0-9 ]+', '', i) for i in blogs]

# %%
##Eliminar Stopwords

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Andrea
# [nltk_data]     Paniagua\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
stopwords=set(stopwords.words('english'))
trendy_words=['im','rt','jk','btw','lol','yolo','lmao','lmfao','fb','like','get']
for i in trendy_words:
    stopwords.add(i)

# %%
##mostrar archivos limpios

# %%
tweets_clean=[]
for tweet in tweets:
    word_list=[]
    for word in tweet.split():
        if word not in stopwords:
            word_list.append(word)
    tweets_clean.append(' '.join(word_list))
tweets_clean
# Out:
# ['thanks gonna dc anytime soon love see way way long',
#  'meet someone special youll know heart beat rapidly youll smile reason',
#  'theyve decided fun dont',
#  'tired played lazer tag ran lot ughh going sleep 5 minutes',
#  'words complete stranger made birthday even better',
#  'first cubs game ever wrigley field gorgeous perfect go cubs go',
#  'another day skool due wonderful snow wakes updamn thing',
#  'coo jus work hella tired r u ever cali',
#  'new sundrop commercial hehe love first sight',
#  'need reconnect week',
#  'always wonder guys auctions shows learned talk fast hear djsosnekspqnslanskam',
#  'dammnnnnn catch',
#  'great picture green shirt totally brings eyes',
#  'desk put together room set oh boy oh boy',
#  '',
#  'beauty brainstorming alchemy office sally walker',
#  'looking new band blog month anyone interested',
#  'packing quick move street movers',
#  'ford focus hatchback',
# ...

# %%
blogs_clean=[]
for blog in blogs:
    word_listo=[]
    for word in blog.split():
        if word not in stopwords:
            word_listo.append(word)
    blogs_clean.append(' '.join(word_listo))
blogs_clean
# Out:
# ['years thereafter oil fields platforms named pagan gods',
#  'love mr brown',
#  'chad awesome kids holding fort work later usual kids busy together playing skylander xbox together kyan cashed piggy bank wanted game bad used gift card birthday saving money never taps thing either know wanted bad made count money make sure enough cute watch reaction realized also good job letting lola feel playing letting switch characters loves almost much',
#  'anyways going share home decor inspiration storing folder puter amazing images stored away ready come life home',
#  'graduation season right around corner nancy whipped fun set help graduation cards gifts occasion brings change ones life stamped images memento tuxedo black cut circle nestabilities embossed kraft red cardstock tes new stars impressions plate double sided gives 2 fantastic patterns see use impressions plates tutorial taylor created one pass die cut machine using embossing pad kit need super easy',
# ...
